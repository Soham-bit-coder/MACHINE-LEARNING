# %% [markdown]
# <a href="https://colab.research.google.com/github/Soham-bit-coder/MACHINE-LEARNING/blob/main/SVR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVR

# Generate sample data
X = np.linspace(0, 10, 50).reshape(-1, 1)
y = np.sin(X).ravel()

# Add some noise
y[::5] += 0.5

# Create SVR model
model = SVR(kernel='rbf', C=100, epsilon=0.2, gamma=0.5)

# Train model
model.fit(X, y)

# Predictions
X_test = np.linspace(0, 10, 200).reshape(-1, 1)
y_pred = model.predict(X_test)

# Plot
plt.figure()
plt.scatter(X, y)
plt.plot(X_test, y_pred)
plt.title("Support Vector Regression (RBF Kernel)")
plt.xlabel("X")
plt.ylabel("y")
plt.show()
