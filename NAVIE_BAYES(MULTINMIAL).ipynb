# %% [markdown]
# <a href="https://colab.research.google.com/github/Soham-bit-coder/MACHINE-LEARNING/blob/main/NAVIE_BAYES(MULTINMIAL).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB

# Sample reviews
reviews = [
    "This product is amazing",
    "Very bad quality",
    "I love this phone",
    "Worst purchase ever",
    "Good product",
    "Not worth the money"
]

# Labels (1 = Positive, 0 = Negative)
labels = [1, 0, 1, 0, 1, 0]

# Convert text to numbers
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(reviews)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, labels, test_size=0.2)

# Train model
model = MultinomialNB()
model.fit(X_train, y_train)

# Test review
test_review = ["This product is very good"]
test_vector = vectorizer.transform(test_review)

prediction = model.predict(test_vector)

print("Prediction:", prediction)
# Out:
# Prediction: [1]
