# %% [markdown]
# <a href="https://colab.research.google.com/github/Soham-bit-coder/MACHINE-LEARNING/blob/main/perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# %%
# Input data (AND gate)
X = torch.tensor([[0., 0.],
                  [0., 1.],
                  [1., 0.],
                  [1., 1.]])

y = torch.tensor([[0.],
                  [0.],
                  [0.],
                  [1.]])
# Out:
# [0, 0, 0, 1]

# %%
class perceptron (nn.module):
  def __init__(self):
    super(perceptron,self).__init__()
    self.linear=nn.linear(2,1)
  def forward_pass(self,x):
    return torch.sigmoid(self.linear(x))   #activation

model=perceptron()
criterion=nn.BCELoss()
optimizer=optim.SGD(model.parameter(),lr=0.3)

# %%
# Training loop
for epoch in range(1000):
  output=model(x)
  loss = criterion(outputs, y)
  optimizer.zero_grad()
  loss.backward()
  optimizer.step()

# %%
# testing
with torch.no_grad():
    print("Predictions:")
    print(model(X).round())
